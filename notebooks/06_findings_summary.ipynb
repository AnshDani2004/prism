# %% [markdown]
# # PRISM Notebook 06: Findings Summary
#
# **2-minute interview walkthrough.** See also `research/findings.md`.

# %%
from src.data.database import PrismDatabase
db = PrismDatabase()
print('Phase 1:', db.phase1_checkpoint())
print('Phase 4:', db.phase4_checkpoint())

# %% [markdown]
# ## Research Question
# Do in-play prediction market prices lag after scoring events?
#
# ## Methodology
# Calibrated models vs Kalshi/Polymarket; backtest at touch with fees; 2023 held out.
#
# ## Fill resume bullets after `python scripts/phase5_checkpoint.py`
